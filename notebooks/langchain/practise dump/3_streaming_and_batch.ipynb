# %% [markdown]
# ### Streaming and batch
# - stream content while it is being generated , show output as it is being generated
# - streaming improves ui for responses taking longer time
# - returns iterator that can be rendered

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

from langchain.chat_models import init_chat_model

model = init_chat_model(model="google_genai:gemini-2.5-flash-lite")
model

# model.stream
# for chunk in model.stream("Write a 100 word haiku"):
#     print(chunk.text, end=" | ", flush=True)
# Out:
# Sun | light paints the dew,
# Each drop a tiny, bright jewel,
# Morning | 's gentle kiss.
#
# Whispers in the breeze,
# Leaves dance in a silent ballet,
# Nature's sweet soft song.
#
# Clouds drift, slow and white,
# Across the vast, azure dome,
# Dreams take flight on |  air.
#
# River's gentle flow,
# Carries secrets, old and deep,
# Time's steady embrace.
#
# Stars begin to gleam,
# Darkness wraps the sleeping world,
# Peace in quiet night. |  |

# %% [markdown]
# ### BATCH

# %%
# responses = model.batch([
#     "Write a 100 word haiku",
#     "Write a 100 word poem about the sea",
# ], max_concurrency=2)

# for response in responses:
#     print(response.text)
